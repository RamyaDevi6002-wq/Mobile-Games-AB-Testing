# %%
# !unzip archive.zip
# Out:
# Archive:  archive.zip
#   inflating: cookie_cats.csv

# %%
import pandas as pd
df=pd.read_csv("cookie_cats.csv")
df.head()
# Out:
#    userid  version  sum_gamerounds  retention_1  retention_7
# 0     116  gate_30               3        False        False
# 1     337  gate_30              38         True        False
# 2     377  gate_40             165         True        False
# 3     483  gate_40               1        False        False
# 4     488  gate_40             179         True         True

# %%
df.describe()
# Out:
#              userid  sum_gamerounds
# count  9.018900e+04    90189.000000
# mean   4.998412e+06       51.872457
# std    2.883286e+06      195.050858
# min    1.160000e+02        0.000000
# 25%    2.512230e+06        5.000000
# 50%    4.995815e+06       16.000000
# 75%    7.496452e+06       51.000000
# max    9.999861e+06    49854.000000

# %%
df.groupby("version")["sum_gamerounds"].mean()
# Out:
# version
# gate_30    52.456264
# gate_40    51.298776
# Name: sum_gamerounds, dtype: float64

# %%
from scipy import stats
group_A=df[df["version"]=='gate_30']["sum_gamerounds"]
group_B=df[df["version"]=='gate_40']["sum_gamerounds"]
t_stat,p_value=stats.ttest_ind(group_A,group_B)
print("t_statistics:" ,t_stat)
print("P_value:", p_value)
# Out:
# t_statistics: 0.8910426211362967
# P_value: 0.37290868247405207

# %%
# !unzip -o archive.zip
# Out:
# Archive:  archive.zip
#   inflating: cookie_cats.csv

# %%
import pandas as pd
from scipy import stats

df = pd.read_csv("cookie_cats.csv")

retention_table = pd.crosstab(df["version"], df["retention_1"])
print("--- Retention Table ---")
print(retention_table)


chi2, p_val_chi, dof, ex = stats.chi2_contingency(retention_table)
print("\nChi-Square, P-Value:", p_val_chi)
# Out:
# --- Retention Table ---
# retention_1  False  True
# version
# gate_30      24666  20034
# gate_40      25370  20119
#
# Chi-Square, P-Value: 0.07550476210309086

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1-Day Retention Rate Graph
plt.figure(figsize=(6, 4))
sns.barplot(x='version', y='retention_1', data=df, errorbar=None, palette='Set2')
plt.title('1-Day Retention Rate by Game Version')
plt.ylabel('Retention Rate')
plt.xlabel('Game Version')
plt.show()
# Out:
# /tmp/ipykernel_3291/454549244.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='version', y='retention_1', data=df, errorbar=None, palette='Set2')
